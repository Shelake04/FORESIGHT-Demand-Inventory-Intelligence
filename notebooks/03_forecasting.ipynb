# %% [markdown]
# # Forecasting
# Compare seasonal naive with one feature-based candidate using chronological rolling-origin WAPE.

# %%
from src.pipeline import run_pipeline
from src.forecast import evaluate_backtests
weekly = run_pipeline()
results = evaluate_backtests(weekly, horizon=6)
results

# %% [markdown]
# The selected production model must follow measured backtest performance; no random time-series split is used.
