# %% [markdown]
# # 1. Objective
# Audit the generated FORESIGHT tables, relationships, grain, and quality constraints.

# %%
from src.pipeline import load_raw_data, validate_raw_data
data = load_raw_data()
summary = validate_raw_data(data)
summary

# %% [markdown]
# The loader preserves literal `None` labels so valid categorical values are not treated as missing.
